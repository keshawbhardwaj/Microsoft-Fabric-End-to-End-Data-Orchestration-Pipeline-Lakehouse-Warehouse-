# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql.functions import *
from pyspark.sql import SparkSession
# Out:
# StatementMeta(, 2b8e0c8d-9f22-4d69-b581-cf309196014d, 3, Finished, Available, Finished)

# %%
df = spark.read.csv("Files/netflix_titles.csv",header=True,inferSchema=True)

display(df)
# Out:
# StatementMeta(, 2b8e0c8d-9f22-4d69-b581-cf309196014d, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 1c95064a-990d-4fbe-a281-bf406d2bebb4)

# %%
#load to table

df.write.mode("overwrite").saveAsTable("Netflix_Series_description")
# Out:
# StatementMeta(, 2b8e0c8d-9f22-4d69-b581-cf309196014d, 6, Finished, Available, Finished)
